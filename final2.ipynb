# %%
#import tensorflow as tf
#print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %%
#%lsmagic

# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import os
import json
import datetime as dt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]
plt.rcParams['font.size'] = 14
import seaborn as sns
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Add
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input

import random
import tensorflow_addons as tfa
import math

from tensorflow.keras import layers
start = dt.datetime.now()

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=3072)])
  except RuntimeError as e:
    print(e)

# %%
DP_DIR = 'D:/Desktop/shuffle-csvs/'
INPUT_DIR = 'D:/Desktop/'

BASE_SIZE = 256
NCSVS = 100
NCATS = 340
np.random.seed(seed=1987)
tf.random.set_seed(seed=1987)

def f2cat(filename: str) -> str:
    return filename.split('.')[0]

def list_all_categories():
    files = os.listdir(os.path.join(INPUT_DIR, 'train_simplified'))
    return sorted([f2cat(f) for f in files], key=str.lower)

# %%
def apk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    if len(predicted) > k:
        predicted = predicted[:k]
    score = 0.0
    num_hits = 0.0
    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    if not actual:
        return 0.0
    return score / min(len(actual), k)

def mapk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    return np.mean([apk(a, p, k) for a, p in zip(actual, predicted)])

def preds2catids(predictions):
    return pd.DataFrame(np.argsort(-predictions, axis=1)[:, :3], columns=['a', 'b', 'c'])

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

# %% [markdown]
# MobileNet
#
# MobileNets are based on a streamlined architecture that uses depthwise separable convolutions to build light weight deep neural networks.
#
# MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Applications

# %%
STEPS = 10000
EPOCHS = 100
size = 64
batchsize = 980

# %%
def toy_resnet(input_shape=(size, size, 1), classes=NCATS):
    
    inputs = keras.Input(shape=(64, 64, 1), name="img")
    
    x = layers.ZeroPadding2D((3,3))(inputs)
    
    #---------
    x = layers.Conv2D(64, (7, 7), strides=(2, 2))(x)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2))(x)
    
    
    #---------conv 1 a
    x_1 = x
    x = layers.Conv2D(64, (1, 1), strides = (2,2))(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(64, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(256, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x_1 = layers.Conv2D(256, kernel_size = (1, 1), strides = (2,2), padding = 'valid')(x_1)
    x_1 = layers.BatchNormalization(axis=3)(x_1)
    
    #=========
    x = Add()([x,x_1])
    x = Activation('elu')(x)    
    
     
    #---------id 1 a
    x_2 = x
    x = layers.Conv2D(64, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(64, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(256, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x = Add()([x,x_2])
    x = Activation('elu')(x)
    
    #---------id 2 a
    x_3 = x
    x = layers.Conv2D(64, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(64, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(256, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
        
    #=========
    x = Add()([x,x_3])
    x = Activation('elu')(x)
    
    
    #---------conv 1 b
    x_4 = x
    x = layers.Conv2D(128, (1, 1), strides = (2,2))(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(128, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(512, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x_4 = layers.Conv2D(512, kernel_size = (1, 1), strides = (2,2), padding = 'valid')(x_4)
    x_4 = layers.BatchNormalization(axis=3)(x_4)
    
    #=========
    x = Add()([x,x_4])
    x = Activation('elu')(x)    
    
    
    #---------id 1 b
    x_5 = x
    x = layers.Conv2D(128, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(128, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(512, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x = Add()([x,x_5])
    x = Activation('elu')(x) 
    
    
    #---------id 2 b
    x_6 = x
    x = layers.Conv2D(128, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(128, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(512, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x = Add()([x,x_6])
    x = Activation('elu')(x) 
    
    
    #---------id 2 c
    x_7 = x
    x = layers.Conv2D(128, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(128, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('elu')(x)
    
    #=========
    x = layers.Conv2D(512, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x = Add()([x,x_7])
    x = Activation('elu')(x) 
    
    
    #---------
    x = layers.AveragePooling2D()(x)
    x = layers.Flatten()(x)
    x = Dense(NCATS, activation = 'softmax')(x)
    
    model = keras.Model(inputs, x, name="toy_resnet")
    
    return model

# %%
model = toy_resnet(input_shape=(size, size, 1), classes=NCATS)
model.compile(optimizer=Adam(lr=0.002), loss='categorical_crossentropy',
              metrics=[categorical_crossentropy, categorical_accuracy, top_3_accuracy])
print(model.summary())
# Out:
# Model: "toy_resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 70, 1)    0           img[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   3200        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 15, 15, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 64)     4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 64)     256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 8, 8, 64)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 64)     36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 64)     256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 8, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 256)    16640       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 256)    16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 256)    1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 256)    1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 8, 256)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 8, 8, 256)    0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 64)     16448       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 64)     256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 8, 8, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 64)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 256)    16640       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 256)    1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 256)    0           batch_normalization_7[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 256)    0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 64)     16448       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 64)     256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 64)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 64)     36928       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 64)     256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 8, 8, 64)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    16640       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 256)    0           batch_normalization_10[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 256)    0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 128)    32896       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 128)    147584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 128)    512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 128)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 512)    66048       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 512)    131584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 512)    2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 512)    2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 4, 512)    0           batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 512)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 128)    65664       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 128)    147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 128)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    66048       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 512)    0           batch_normalization_17[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 512)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 128)    65664       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 128)    512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 128)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 128)    147584      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 128)    512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 128)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 512)    66048       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 512)    0           batch_normalization_20[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 128)    65664       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 128)    512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 128)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 128)    147584      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 128)    512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 128)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 512)    66048       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 512)    2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           batch_normalization_23[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 2, 2, 512)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 340)          696660      flatten[0][0]
# ==================================================================================================
# Total params: 2,150,484
# Trainable params: 2,140,372
# Non-trainable params: 10,112
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Training with Image Generator

# %%
def draw_cv2(raw_strokes, size=256, lw=6, time_color=True):
    img = np.zeros((BASE_SIZE, BASE_SIZE), np.uint8)
    for t, stroke in enumerate(raw_strokes):
        for i in range(len(stroke[0]) - 1):
            color = 255 - min(t, 10) * 13 if time_color else 255
            _ = cv2.line(img, (stroke[0][i], stroke[1][i]),
                         (stroke[0][i + 1], stroke[1][i + 1]), color, lw)
    if size != BASE_SIZE:
        return cv2.resize(img, (size, size))
    else:
        return img

def image_generator_xd(size, batchsize, ks, lw=6, time_color=True):
    while True:
        for k in np.random.permutation(ks):
            filename = os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(k))
            for df in pd.read_csv(filename, chunksize=batchsize):
                df['drawing'] = df['drawing'].apply(json.loads)
                x = np.zeros((len(df), size, size, 1))
                for i, raw_strokes in enumerate(df.drawing.values):
                    r = random.randint(0,19)
                    if(r == 1):
                        r1 = random.randint(0,len(raw_strokes)-1)
                        r2 = random.randint(0,len(raw_strokes[r1][0])-1)
                        r3 = random.randint(0,len(raw_strokes[r1][1])-1)
                        raw_strokes[r1][0][r2] = random.randint(0,256)
                        raw_strokes[r1][1][r3] = random.randint(0,256)                    
                    x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw,
                                             time_color=time_color)
                    r = random.randint(0,19)
                    if(r == 1):
                        x[i, :, :, 0] = tfa.image.rotate(x[i, :, :, 0], random.randint(-30,30) * math.pi / 180, interpolation='BILINEAR')
                x = preprocess_input(x).astype(np.float32)
                y = keras.utils.to_categorical(df.y, num_classes=NCATS)
                yield x, y

def df_to_image_array_xd(df, size, lw=6, time_color=True):
    df['drawing'] = df['drawing'].apply(json.loads)
    x = np.zeros((len(df), size, size, 1))
    for i, raw_strokes in enumerate(df.drawing.values):
        x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw, time_color=time_color)
    x = preprocess_input(x).astype(np.float32)
    return x

# %%
valid_df = pd.read_csv(os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(NCSVS - 1)), nrows=34000)
x_valid = df_to_image_array_xd(valid_df, size)
y_valid = keras.utils.to_categorical(valid_df.y, num_classes=NCATS)
print(x_valid.shape, y_valid.shape)
print('Validation array memory {:.2f} GB'.format(x_valid.nbytes / 1024.**3 ))
# Out:
# (34000, 64, 64, 1) (34000, 340)
# Validation array memory 0.52 GB

# %%
train_datagen = image_generator_xd(size=size, batchsize=batchsize, ks=range(NCSVS - 1))

# %%
x, y = next(train_datagen)
n = 8
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n**2):
    ax = axs[i // n, i % n]
    (-x[i]+1)/2
    ax.imshow((-x[i, :, :, 0] + 1)/2, cmap=plt.cm.gray)
    ax.axis('off')
plt.tight_layout()
fig.savefig('gs.png', dpi=300)
plt.show();

# %%
# %%timeit
x, y = next(train_datagen)
# Out:
# 249 ms ± 13.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_delta=0.001,
                          mode='max', min_lr=1e-5, verbose=1),
    ModelCheckpoint('modelelperepoch.h5', monitor='val_top_3_accuracy', mode='max', save_best_only=True,
                    save_weights_only=False),
    EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto',
                                    baseline=None, restore_best_weights=False)

]
hists = []
hist = model.fit_generator(
    train_datagen, steps_per_epoch=STEPS, epochs=100, verbose=1,
    validation_data=(x_valid, y_valid),
    callbacks = callbacks
)
hists.append(hist)
# Out:
# WARNING:tensorflow:From <ipython-input-15-19898eed6149>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 10000/10000 [==============================] - 4368s 437ms/step - loss: 1.3466 - categorical_crossentropy: 1.3466 - categorical_accuracy: 0.6702 - top_3_accuracy: 0.8386 - val_loss: 1.1290 - val_categorical_crossentropy: 1.1290 - val_categorical_accuracy: 0.7151 - val_top_3_accuracy: 0.8739
# Epoch 2/100
# 10000/10000 [==============================] - 4281s 428ms/step - loss: 1.0561 - categorical_crossentropy: 1.0561 - categorical_accuracy: 0.7330 - top_3_accuracy: 0.8844 - val_loss: 1.0217 - val_categorical_crossentropy: 1.0217 - val_categorical_accuracy: 0.7426 - val_top_3_accuracy: 0.8908
# Epoch 3/100
# 10000/10000 [==============================] - 4077s 408ms/step - loss: 0.9804 - categorical_crossentropy: 0.9804 - categorical_accuracy: 0.7503 - top_3_accuracy: 0.8951 - val_loss: 0.9635 - val_categorical_crossentropy: 0.9635 - val_categorical_accuracy: 0.7549 - val_top_3_accuracy: 0.8976
# Epoch 4/100
# 10000/10000 [==============================] - ETA: 0s - loss: 0.9358 - categorical_crossentropy: 0.9358 - categorical_accuracy: 0.7602 - top_3_accuracy: 0.9012
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 10000/10000 [==============================] - 4217s 422ms/step - loss: 0.9358 - categorical_crossentropy: 0.9358 - categorical_accuracy: 0.7602 - top_3_accuracy: 0.9012 - val_loss: 0.9438 - val_categorical_crossentropy: 0.9438 - val_categorical_accuracy: 0.7593 - val_top_3_accuracy: 0.9009
# Epoch 5/100
# 10000/10000 [==============================] - 3832s 383ms/step - loss: 0.8427 - categorical_crossentropy: 0.8427 - categorical_accuracy: 0.7834 - top_3_accuracy: 0.9131 - val_loss: 0.8558 - val_categorical_crossentropy: 0.8558 - val_categorical_accuracy: 0.7819 - val_top_3_accuracy: 0.9120
# Epoch 6/100
# 10000/10000 [==============================] - 3898s 390ms/step - loss: 0.8210 - categorical_crossentropy: 0.8210 - categorical_accuracy: 0.7884 - top_3_accuracy: 0.9160 - val_loss: 0.8503 - val_categorical_crossentropy: 0.8503 - val_categorical_accuracy: 0.7817 - val_top_3_accuracy: 0.9139
# Epoch 7/100
# 10000/10000 [==============================] - ETA: 0s - loss: 0.8112 - categorical_crossentropy: 0.8112 - categorical_accuracy: 0.7907 - top_3_accuracy: 0.9172
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 8.000000379979611e-05.
# 10000/10000 [==============================] - 3819s 382ms/step - loss: 0.8112 - categorical_crossentropy: 0.8112 - categorical_accuracy: 0.7907 - top_3_accuracy: 0.9172 - val_loss: 0.8532 - val_categorical_crossentropy: 0.8532 - val_categorical_accuracy: 0.7834 - val_top_3_accuracy: 0.9124
# Epoch 8/100
# 10000/10000 [==============================] - 3697s 370ms/step - loss: 0.7889 - categorical_crossentropy: 0.7889 - categorical_accuracy: 0.7963 - top_3_accuracy: 0.9200 - val_loss: 0.8386 - val_categorical_crossentropy: 0.8386 - val_categorical_accuracy: 0.7868 - val_top_3_accuracy: 0.9144
# Epoch 9/100
# 10000/10000 [==============================] - 3587s 359ms/step - loss: 0.7822 - categorical_crossentropy: 0.7822 - categorical_accuracy: 0.7980 - top_3_accuracy: 0.9208 - val_loss: 0.8404 - val_categorical_crossentropy: 0.8404 - val_categorical_accuracy: 0.7868 - val_top_3_accuracy: 0.9138
# Epoch 10/100
# 10000/10000 [==============================] - ETA: 0s - loss: 0.7786 - categorical_crossentropy: 0.7786 - categorical_accuracy: 0.7988 - top_3_accuracy: 0.9211
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.6000001050997525e-05.
# 10000/10000 [==============================] - 3603s 360ms/step - loss: 0.7786 - categorical_crossentropy: 0.7786 - categorical_accuracy: 0.7988 - top_3_accuracy: 0.9211 - val_loss: 0.8399 - val_categorical_crossentropy: 0.8399 - val_categorical_accuracy: 0.7866 - val_top_3_accuracy: 0.9147
# Epoch 11/100
# 10000/10000 [==============================] - 3611s 361ms/step - loss: 0.7735 - categorical_crossentropy: 0.7735 - categorical_accuracy: 0.8003 - top_3_accuracy: 0.9218 - val_loss: 0.8387 - val_categorical_crossentropy: 0.8387 - val_categorical_accuracy: 0.7877 - val_top_3_accuracy: 0.9149
# Epoch 12/100
# 10000/10000 [==============================] - 3630s 363ms/step - loss: 0.7738 - categorical_crossentropy: 0.7738 - categorical_accuracy: 0.8001 - top_3_accuracy: 0.9218 - val_loss: 0.8383 - val_categorical_crossentropy: 0.8383 - val_categorical_accuracy: 0.7877 - val_top_3_accuracy: 0.9149
# Epoch 13/100
# 10000/10000 [==============================] - ETA: 0s - loss: 0.7726 - categorical_crossentropy: 0.7726 - categorical_accuracy: 0.8003 - top_3_accuracy: 0.9220
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1e-05.
# 10000/10000 [==============================] - 3620s 362ms/step - loss: 0.7726 - categorical_crossentropy: 0.7726 - categorical_accuracy: 0.8003 - top_3_accuracy: 0.9220 - val_loss: 0.8383 - val_categorical_crossentropy: 0.8383 - val_categorical_accuracy: 0.7878 - val_top_3_accuracy: 0.9149
# Epoch 14/100
# 10000/10000 [==============================] - 3617s 362ms/step - loss: 0.7708 - categorical_crossentropy: 0.7708 - categorical_accuracy: 0.8009 - top_3_accuracy: 0.9222 - val_loss: 0.8383 - val_categorical_crossentropy: 0.8383 - val_categorical_accuracy: 0.7879 - val_top_3_accuracy: 0.9146
# Epoch 15/100
# 10000/10000 [==============================] - 3602s 360ms/step - loss: 0.7719 - categorical_crossentropy: 0.7719 - categorical_accuracy: 0.8006 - top_3_accuracy: 0.9219 - val_loss: 0.8383 - val_categorical_crossentropy: 0.8383 - val_categorical_accuracy: 0.7877 - val_top_3_accuracy: 0.9147
# Epoch 16/100
# 10000/10000 [==============================] - 3591s 359ms/step - loss: 0.7699 - categorical_crossentropy: 0.7699 - categorical_accuracy: 0.8011 - top_3_accuracy: 0.9222 - val_loss: 0.8387 - val_categorical_crossentropy: 0.8387 - val_categorical_accuracy: 0.7883 - val_top_3_accuracy: 0.9145
# Epoch 17/100
# 10000/10000 [==============================] - 3926s 393ms/step - loss: 0.7694 - categorical_crossentropy: 0.7694 - categorical_accuracy: 0.8010 - top_3_accuracy: 0.9223 - val_loss: 0.8387 - val_categorical_crossentropy: 0.8387 - val_categorical_accuracy: 0.7877 - val_top_3_accuracy: 0.9146
# Epoch 18/100
# 10000/10000 [==============================] - 3967s 397ms/step - loss: 0.7689 - categorical_crossentropy: 0.7689 - categorical_accuracy: 0.8014 - top_3_accuracy: 0.9223 - val_loss: 0.8388 - val_categorical_crossentropy: 0.8388 - val_categorical_accuracy: 0.7878 - val_top_3_accuracy: 0.9149
# Epoch 19/100
# 10000/10000 [==============================] - 4038s 404ms/step - loss: 0.7718 - categorical_crossentropy: 0.7718 - categorical_accuracy: 0.8006 - top_3_accuracy: 0.9220 - val_loss: 0.8384 - val_categorical_crossentropy: 0.8384 - val_categorical_accuracy: 0.7877 - val_top_3_accuracy: 0.9148
# Epoch 20/100
# 10000/10000 [==============================] - 4000s 400ms/step - loss: 0.7694 - categorical_crossentropy: 0.7694 - categorical_accuracy: 0.8012 - top_3_accuracy: 0.9223 - val_loss: 0.8386 - val_categorical_crossentropy: 0.8386 - val_categorical_accuracy: 0.7876 - val_top_3_accuracy: 0.9148
# Epoch 21/100
# 10000/10000 [==============================] - 3985s 398ms/step - loss: 0.7683 - categorical_crossentropy: 0.7683 - categorical_accuracy: 0.8013 - top_3_accuracy: 0.9224 - val_loss: 0.8387 - val_categorical_crossentropy: 0.8387 - val_categorical_accuracy: 0.7880 - val_top_3_accuracy: 0.9147
# Epoch 22/100
# 10000/10000 [==============================] - 3941s 394ms/step - loss: 0.7692 - categorical_crossentropy: 0.7692 - categorical_accuracy: 0.8012 - top_3_accuracy: 0.9223 - val_loss: 0.8387 - val_categorical_crossentropy: 0.8387 - val_categorical_accuracy: 0.7881 - val_top_3_accuracy: 0.9148
# Epoch 23/100
# 10000/10000 [==============================] - 3804s 380ms/step - loss: 0.7692 - categorical_crossentropy: 0.7692 - categorical_accuracy: 0.8013 - top_3_accuracy: 0.9223 - val_loss: 0.8385 - val_categorical_crossentropy: 0.8385 - val_categorical_accuracy: 0.7876 - val_top_3_accuracy: 0.9146
# Epoch 24/100
# 10000/10000 [==============================] - 3871s 387ms/step - loss: 0.7672 - categorical_crossentropy: 0.7672 - categorical_accuracy: 0.8016 - top_3_accuracy: 0.9226 - val_loss: 0.8393 - val_categorical_crossentropy: 0.8393 - val_categorical_accuracy: 0.7881 - val_top_3_accuracy: 0.9148

# %%
hist_df = pd.concat([pd.DataFrame(hist.history) for hist in hists], sort=True)
hist_df.index = np.arange(1, len(hist_df)+1)
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(16, 10))
axs[0].plot(hist_df.val_categorical_accuracy, lw=5, label='Validation Accuracy')
axs[0].plot(hist_df.categorical_accuracy, lw=5, label='Training Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].grid()
axs[0].legend(loc=0)
axs[1].plot(hist_df.val_categorical_crossentropy, lw=5, label='Validation MLogLoss')
axs[1].plot(hist_df.categorical_crossentropy, lw=5, label='Training MLogLoss')
axs[1].set_ylabel('MLogLoss')
axs[1].set_xlabel('Epoch')
axs[1].grid()
axs[1].legend(loc=0)
fig.savefig('hist.png', dpi=300)
plt.show();

# %%
valid_predictions = model.predict(x_valid, batch_size=128, verbose=1)
map3 = mapk(valid_df[['y']].values, preds2catids(valid_predictions).values)
print('Map3: {:.3f}'.format(map3))
# Out:
# 266/266 [==============================] - 2s 9ms/step
# Map3: 0.843

# %%
hist_df = pd.concat([pd.DataFrame(hist.history) for hist in hists], sort=True)
hist_df.index = np.arange(1, len(hist_df)+1)
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(16, 10))
axs[0].plot(hist_df.val_top_3_accuracy, lw=5, label='Validation Accuracy')
axs[0].plot(hist_df.top_3_accuracy, lw=5, label='Training Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].grid()
axs[0].legend(loc=0)
axs[1].plot(hist_df.val_categorical_crossentropy, lw=5, label='Validation MLogLoss')
axs[1].plot(hist_df.categorical_crossentropy, lw=5, label='Training MLogLoss')
axs[1].set_ylabel('MLogLoss')
axs[1].set_xlabel('Epoch')
axs[1].grid()
axs[1].legend(loc=0)
fig.savefig('hist.png', dpi=300)
plt.show();
