# %%
#import tensorflow as tf
#print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %%
#%lsmagic

# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import os
import json
import datetime as dt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]
plt.rcParams['font.size'] = 14
import seaborn as sns
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Add
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input

import random

from tensorflow.keras import layers
start = dt.datetime.now()

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=3072)])
  except RuntimeError as e:
    print(e)

# %%
DP_DIR = 'D:/Desktop/shuffle-csvs/'
INPUT_DIR = 'D:Desktop/'

BASE_SIZE = 256
NCSVS = 100
NCATS = 340
np.random.seed(seed=1987)
tf.random.set_seed(seed=1987)

def f2cat(filename: str) -> str:
    return filename.split('.')[0]

def list_all_categories():
    files = os.listdir(os.path.join(INPUT_DIR, 'train_simplified'))
    return sorted([f2cat(f) for f in files], key=str.lower)

# %%
def apk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    if len(predicted) > k:
        predicted = predicted[:k]
    score = 0.0
    num_hits = 0.0
    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    if not actual:
        return 0.0
    return score / min(len(actual), k)

def mapk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    return np.mean([apk(a, p, k) for a, p in zip(actual, predicted)])

def preds2catids(predictions):
    return pd.DataFrame(np.argsort(-predictions, axis=1)[:, :3], columns=['a', 'b', 'c'])

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

# %% [markdown]
# MobileNet
#
# MobileNets are based on a streamlined architecture that uses depthwise separable convolutions to build light weight deep neural networks.
#
# MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Applications

# %%
STEPS = 10000
EPOCHS = 100
size = 64
batchsize = 980

# %%
def toy_resnet(input_shape=(size, size, 1), classes=NCATS):
    
    inputs = keras.Input(shape=(64, 64, 1), name="img")
    
    x = layers.ZeroPadding2D((3,3))(inputs)
    
    #---------
    x = layers.Conv2D(64, (7, 7), strides=(2, 2))(x)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2))(x)
    
    
    #---------conv 1 a
    x_1 = x
    x = layers.Conv2D(64, (1, 1), strides = (2,2))(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(64, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(256, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x_1 = layers.Conv2D(256, kernel_size = (1, 1), strides = (2,2), padding = 'valid')(x_1)
    x_1 = layers.BatchNormalization(axis=3)(x_1)
    
    #=========
    x = Add()([x,x_1])
    x = Activation('relu')(x)    
    
     
    #---------id 1 a
    x_2 = x
    x = layers.Conv2D(64, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(64, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(256, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x = Add()([x,x_2])
    x = Activation('relu')(x)
    
    #---------id 2 a
    x_3 = x
    x = layers.Conv2D(64, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(64, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(256, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
        
    #=========
    x = Add()([x,x_3])
    x = Activation('relu')(x)
    
    
    #---------conv 1 b
    x_4 = x
    x = layers.Conv2D(128, (1, 1), strides = (2,2))(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(128, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(512, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x_4 = layers.Conv2D(512, kernel_size = (1, 1), strides = (2,2), padding = 'valid')(x_4)
    x_4 = layers.BatchNormalization(axis=3)(x_4)
    
    #=========
    x = Add()([x,x_4])
    x = Activation('relu')(x)    
    
    
    #---------id 1 b
    x_5 = x
    x = layers.Conv2D(128, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(128, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(512, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x = Add()([x,x_5])
    x = Activation('relu')(x) 
    
    
    #---------id 2 b
    x_6 = x
    x = layers.Conv2D(128, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(128, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(512, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x = Add()([x,x_6])
    x = Activation('relu')(x) 
    
    
    #---------id 2 c
    x_7 = x
    x = layers.Conv2D(128, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(128, kernel_size = (3, 3), strides = (1,1), padding = 'same')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    
    #=========
    x = layers.Conv2D(512, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(x) 
    x = layers.BatchNormalization(axis=3)(x)
    
    #=========
    x = Add()([x,x_7])
    x = Activation('relu')(x) 
    
    
    #---------
    x = layers.AveragePooling2D()(x)
    x = layers.Flatten()(x)
    x = Dense(NCATS, activation = 'softmax')(x)
    
    model = keras.Model(inputs, x, name="toy_resnet")
    
    return model

# %%
model = toy_resnet(input_shape=(size, size, 1), classes=NCATS)
model.compile(optimizer=Adam(lr=0.002), loss='categorical_crossentropy',
              metrics=[categorical_crossentropy, categorical_accuracy, top_3_accuracy])
print(model.summary())
# Out:
# Model: "toy_resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 70, 70, 1)    0           img[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   3200        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 15, 15, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 64)     256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 64)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 64)     36928       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 64)     256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 64)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 256)    16640       activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 256)    16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 256)    1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 256)    0           batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 64)     16448       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 64)     256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 64)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 64)     36928       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 64)     256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 64)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 256)    16640       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 256)    1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 256)    0           batch_normalization_31[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 256)    0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 64)     16448       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 64)     256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 64)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 64)     36928       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 64)     256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 64)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 256)    16640       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 256)    1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 256)    0           batch_normalization_34[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 256)    0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 4, 4, 128)    32896       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 4, 4, 128)    512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 128)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 128)    147584      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 4, 4, 128)    512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 128)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 512)    66048       activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 512)    131584      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 4, 4, 512)    2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 4, 4, 512)    2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 512)    0           batch_normalization_37[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 512)    0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 128)    65664       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 4, 4, 128)    512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 128)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 128)    147584      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 4, 4, 128)    512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 4, 4, 128)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 512)    66048       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 4, 4, 512)    2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 512)    0           batch_normalization_41[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 4, 4, 512)    0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 4, 4, 128)    65664       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 4, 4, 128)    512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 4, 4, 128)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 4, 4, 128)    147584      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 128)    512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 4, 4, 128)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 4, 4, 512)    66048       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 512)    2048        conv2d_44[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 512)    0           batch_normalization_44[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 4, 4, 512)    0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 128)    65664       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 4, 4, 128)    512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 4, 4, 128)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 128)    147584      activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 128)    512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 4, 4, 128)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 512)    66048       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 512)    2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, 4, 512)    0           batch_normalization_47[0][0]
#                                                                  activation_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 4, 4, 512)    0           add_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 2, 2, 512)    0           activation_41[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 340)          696660      flatten_1[0][0]
# ==================================================================================================
# Total params: 2,150,484
# Trainable params: 2,140,372
# Non-trainable params: 10,112
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Training with Image Generator

# %%
def draw_cv2(raw_strokes, size=256, lw=6, time_color=True):
    img = np.zeros((BASE_SIZE, BASE_SIZE), np.uint8)
    for t, stroke in enumerate(raw_strokes):
        for i in range(len(stroke[0]) - 1):
            color = 255 - min(t, 10) * 13 if time_color else 255
            _ = cv2.line(img, (stroke[0][i], stroke[1][i]),
                         (stroke[0][i + 1], stroke[1][i + 1]), color, lw)
    if size != BASE_SIZE:
        return cv2.resize(img, (size, size))
    else:
        return img

def image_generator_xd(size, batchsize, ks, lw=6, time_color=True):
    while True:
        for k in np.random.permutation(ks):
            filename = os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(k))
            for df in pd.read_csv(filename, chunksize=batchsize):
                df['drawing'] = df['drawing'].apply(json.loads)
                x = np.zeros((len(df), size, size, 1))
                for i, raw_strokes in enumerate(df.drawing.values):
                    r = random.randint(0,20)
                    if(r == 1):
                        r1 = random.randint(0,len(raw_strokes)-1)
                        r2 = random.randint(0,len(raw_strokes[r1][0])-1)
                        r3 = random.randint(0,len(raw_strokes[r1][1])-1)
                        raw_strokes[r1][0][r2] = random.randint(0,256)
                        raw_strokes[r1][1][r3] = random.randint(0,256)                    
                    x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw,
                                             time_color=time_color)
                x = preprocess_input(x).astype(np.float32)
                y = keras.utils.to_categorical(df.y, num_classes=NCATS)
                yield x, y

def df_to_image_array_xd(df, size, lw=6, time_color=True):
    df['drawing'] = df['drawing'].apply(json.loads)
    x = np.zeros((len(df), size, size, 1))
    for i, raw_strokes in enumerate(df.drawing.values):
        x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw, time_color=time_color)
    x = preprocess_input(x).astype(np.float32)
    return x

# %%
valid_df = pd.read_csv(os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(NCSVS - 1)), nrows=34000)
x_valid = df_to_image_array_xd(valid_df, size)
y_valid = keras.utils.to_categorical(valid_df.y, num_classes=NCATS)
print(x_valid.shape, y_valid.shape)
print('Validation array memory {:.2f} GB'.format(x_valid.nbytes / 1024.**3 ))
# Out:
# (34000, 64, 64, 1) (34000, 340)
# Validation array memory 0.52 GB

# %%
train_datagen = image_generator_xd(size=size, batchsize=batchsize, ks=range(NCSVS - 1))

# %%
x, y = next(train_datagen)
n = 8
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n**2):
    ax = axs[i // n, i % n]
    (-x[i]+1)/2
    ax.imshow((-x[i, :, :, 0] + 1)/2, cmap=plt.cm.gray)
    ax.axis('off')
plt.tight_layout()
fig.savefig('gs.png', dpi=300)
plt.show();

# %%
# %%timeit
x, y = next(train_datagen)
# Out:
# 111 ms ± 394 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.75, patience=3, min_delta=0.001,
                          mode='max', min_lr=1e-5, verbose=1),
    ModelCheckpoint('modelelperepoch.h5', monitor='val_top_3_accuracy', mode='max', save_best_only=True,
                    save_weights_only=False),
    EarlyStopping(monitor='val_top_3_accuracy', min_delta=0.005, patience=12, verbose=0, mode='auto',
                                    baseline=None, restore_best_weights=False)

]
hists = []
hist = model.fit_generator(
    train_datagen, steps_per_epoch=STEPS, epochs=100, verbose=1,
    validation_data=(x_valid, y_valid),
    callbacks = callbacks
)
hists.append(hist)
# Out:
# WARNING:tensorflow:From <ipython-input-30-8632ed1081fe>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 10000/10000 [==============================] - 1679s 168ms/step - loss: 1.3333 - categorical_crossentropy: 1.3333 - categorical_accuracy: 0.6744 - top_3_accuracy: 0.8400 - val_loss: 1.0866 - val_categorical_crossentropy: 1.0866 - val_categorical_accuracy: 0.7238 - val_top_3_accuracy: 0.8798
# Epoch 2/100
# 10000/10000 [==============================] - 1636s 164ms/step - loss: 1.0233 - categorical_crossentropy: 1.0233 - categorical_accuracy: 0.7398 - top_3_accuracy: 0.8890 - val_loss: 0.9878 - val_categorical_crossentropy: 0.9878 - val_categorical_accuracy: 0.7467 - val_top_3_accuracy: 0.8943
# Epoch 3/100
# 10000/10000 [==============================] - 1633s 163ms/step - loss: 0.9533 - categorical_crossentropy: 0.9533 - categorical_accuracy: 0.7559 - top_3_accuracy: 0.8987 - val_loss: 0.9592 - val_categorical_crossentropy: 0.9592 - val_categorical_accuracy: 0.7562 - val_top_3_accuracy: 0.8999
# Epoch 4/100
# 10000/10000 [==============================] - 1633s 163ms/step - loss: 0.9111 - categorical_crossentropy: 0.9111 - categorical_accuracy: 0.7653 - top_3_accuracy: 0.9044 - val_loss: 0.9346 - val_categorical_crossentropy: 0.9346 - val_categorical_accuracy: 0.7620 - val_top_3_accuracy: 0.9009
# Epoch 5/100
# 10000/10000 [==============================] - 1638s 164ms/step - loss: 0.8844 - categorical_crossentropy: 0.8844 - categorical_accuracy: 0.7714 - top_3_accuracy: 0.9080 - val_loss: 0.9265 - val_categorical_crossentropy: 0.9265 - val_categorical_accuracy: 0.7653 - val_top_3_accuracy: 0.9032
# Epoch 6/100
# 10000/10000 [==============================] - 1633s 163ms/step - loss: 0.8661 - categorical_crossentropy: 0.8661 - categorical_accuracy: 0.7756 - top_3_accuracy: 0.9104 - val_loss: 0.8972 - val_categorical_crossentropy: 0.8972 - val_categorical_accuracy: 0.7719 - val_top_3_accuracy: 0.9075
# Epoch 7/100
# 10000/10000 [==============================] - 1633s 163ms/step - loss: 0.8458 - categorical_crossentropy: 0.8458 - categorical_accuracy: 0.7801 - top_3_accuracy: 0.9131 - val_loss: 0.9019 - val_categorical_crossentropy: 0.9019 - val_categorical_accuracy: 0.7686 - val_top_3_accuracy: 0.9061
# Epoch 8/100
# 10000/10000 [==============================] - 1634s 163ms/step - loss: 0.8374 - categorical_crossentropy: 0.8374 - categorical_accuracy: 0.7821 - top_3_accuracy: 0.9142 - val_loss: 0.9172 - val_categorical_crossentropy: 0.9172 - val_categorical_accuracy: 0.7674 - val_top_3_accuracy: 0.9045
# Epoch 9/100
# 10000/10000 [==============================] - ETA: 0s - loss: 0.8219 - categorical_crossentropy: 0.8219 - categorical_accuracy: 0.7855 - top_3_accuracy: 0.9163
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.001500000071246177.
# 10000/10000 [==============================] - 1633s 163ms/step - loss: 0.8219 - categorical_crossentropy: 0.8219 - categorical_accuracy: 0.7855 - top_3_accuracy: 0.9163 - val_loss: 0.9067 - val_categorical_crossentropy: 0.9067 - val_categorical_accuracy: 0.7670 - val_top_3_accuracy: 0.9071
# Epoch 10/100
# 10000/10000 [==============================] - 1634s 163ms/step - loss: 0.7960 - categorical_crossentropy: 0.7960 - categorical_accuracy: 0.7919 - top_3_accuracy: 0.9194 - val_loss: 0.8828 - val_categorical_crossentropy: 0.8828 - val_categorical_accuracy: 0.7750 - val_top_3_accuracy: 0.9100
# Epoch 11/100
# 10000/10000 [==============================] - 1634s 163ms/step - loss: 0.7835 - categorical_crossentropy: 0.7835 - categorical_accuracy: 0.7948 - top_3_accuracy: 0.9210 - val_loss: 0.8827 - val_categorical_crossentropy: 0.8827 - val_categorical_accuracy: 0.7752 - val_top_3_accuracy: 0.9115
# Epoch 12/100
# 10000/10000 [==============================] - 1634s 163ms/step - loss: 0.7748 - categorical_crossentropy: 0.7748 - categorical_accuracy: 0.7968 - top_3_accuracy: 0.9221 - val_loss: 0.8850 - val_categorical_crossentropy: 0.8850 - val_categorical_accuracy: 0.7754 - val_top_3_accuracy: 0.9105
# Epoch 13/100
# 10000/10000 [==============================] - 1634s 163ms/step - loss: 0.7683 - categorical_crossentropy: 0.7683 - categorical_accuracy: 0.7982 - top_3_accuracy: 0.9229 - val_loss: 0.8848 - val_categorical_crossentropy: 0.8848 - val_categorical_accuracy: 0.7728 - val_top_3_accuracy: 0.9093
# Epoch 14/100
# 10000/10000 [==============================] - ETA: 0s - loss: 0.7625 - categorical_crossentropy: 0.7625 - categorical_accuracy: 0.7994 - top_3_accuracy: 0.9237
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.001125000009778887.
# 10000/10000 [==============================] - 1634s 163ms/step - loss: 0.7625 - categorical_crossentropy: 0.7625 - categorical_accuracy: 0.7994 - top_3_accuracy: 0.9237 - val_loss: 0.8931 - val_categorical_crossentropy: 0.8931 - val_categorical_accuracy: 0.7728 - val_top_3_accuracy: 0.9107
# Epoch 15/100
# 10000/10000 [==============================] - 1632s 163ms/step - loss: 0.7449 - categorical_crossentropy: 0.7449 - categorical_accuracy: 0.8040 - top_3_accuracy: 0.9257 - val_loss: 0.8824 - val_categorical_crossentropy: 0.8824 - val_categorical_accuracy: 0.7775 - val_top_3_accuracy: 0.9108
# Epoch 16/100
# 10000/10000 [==============================] - 1625s 162ms/step - loss: 0.7348 - categorical_crossentropy: 0.7348 - categorical_accuracy: 0.8064 - top_3_accuracy: 0.9269 - val_loss: 0.8921 - val_categorical_crossentropy: 0.8921 - val_categorical_accuracy: 0.7735 - val_top_3_accuracy: 0.9103
# Epoch 17/100
# 10000/10000 [==============================] - ETA: 0s - loss: 0.7284 - categorical_crossentropy: 0.7284 - categorical_accuracy: 0.8078 - top_3_accuracy: 0.9276
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0008437499636784196.
# 10000/10000 [==============================] - 1625s 162ms/step - loss: 0.7284 - categorical_crossentropy: 0.7284 - categorical_accuracy: 0.8078 - top_3_accuracy: 0.9276 - val_loss: 0.8910 - val_categorical_crossentropy: 0.8910 - val_categorical_accuracy: 0.7768 - val_top_3_accuracy: 0.9106
# Epoch 18/100
# 10000/10000 [==============================] - 1626s 163ms/step - loss: 0.7137 - categorical_crossentropy: 0.7137 - categorical_accuracy: 0.8119 - top_3_accuracy: 0.9294 - val_loss: 0.8873 - val_categorical_crossentropy: 0.8873 - val_categorical_accuracy: 0.7769 - val_top_3_accuracy: 0.9115

# %%
hist_df = pd.concat([pd.DataFrame(hist.history) for hist in hists], sort=True)
hist_df.index = np.arange(1, len(hist_df)+1)
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(16, 10))
axs[0].plot(hist_df.val_categorical_accuracy, lw=5, label='Validation Accuracy')
axs[0].plot(hist_df.categorical_accuracy, lw=5, label='Training Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].grid()
axs[0].legend(loc=0)
axs[1].plot(hist_df.val_categorical_crossentropy, lw=5, label='Validation MLogLoss')
axs[1].plot(hist_df.categorical_crossentropy, lw=5, label='Training MLogLoss')
axs[1].set_ylabel('MLogLoss')
axs[1].set_xlabel('Epoch')
axs[1].grid()
axs[1].legend(loc=0)
fig.savefig('hist.png', dpi=300)
plt.show();

# %%
valid_predictions = model.predict(x_valid, batch_size=128, verbose=1)
map3 = mapk(valid_df[['y']].values, preds2catids(valid_predictions).values)
print('Map3: {:.3f}'.format(map3))
# Out:
#   1/266 [..............................] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_predict_batch_end` time: 0.0050s). Check your callbacks.
# 266/266 [==============================] - 2s 7ms/step
# Map3: 0.836

# %%
#model.save('my_modelel.h5')
